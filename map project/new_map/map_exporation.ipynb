# %% [markdown]
# # Arc GIS map dashboard Trial

# %% [markdown]
# # References
# + https://developers.arcgis.com/python/latest/guide/introduction-to-storymaps/

# %%
from arcgis.gis import GIS
from arcgis.apps import storymap
from arcgis.apps.storymap import StoryMap, Themes, Cover
from arcgis.apps.storymap.story_content import Text, TextStyles, Image, Image360, Gallery, Separator, Audio, Video, Map, Button, Sidecar, SidecarSlide, Swipe
from arcgis.map import Map
from arcgis.layers import Service
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from arcgis.gis import GIS
#       2 from arcgis.apps import storymap
#       3 from arcgis.apps.storymap import StoryMap, Themes, Cover
#       4 from arcgis.apps.storymap.story_content import Text, TextStyles, Image, Image360, Gallery, Separator, Audio, Video, Map, Button, Sidecar, SidecarSlide, Swipe
#
# ModuleNotFoundError: No module named 'arcgis'
