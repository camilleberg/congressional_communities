# %% [markdown]
# # Map Trial using Folium

# %% [markdown]
# Using https://www.kaggle.com/code/ifeanyichukwunwobodo/geospatial-analysis-using-folium-and-plotly/notebook

# %%
import math #for basic maths calculation 
import numpy #for linear algebra
import pandas as pd # for data manipulation and basic data visualization

# For Data Visualization
import plotly.express as px

# for geographical analysis we use
import geopandas as gpd #To read our data 
import folium #for interactive maps
from folium import Circle, Marker #to select the maptype we want to use
from folium.plugins import HeatMap, MarkerCluster #for plugins
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 9
#       5 # For Data Visualization
#       6 import plotly.express as px
#       7
#       8 # for geographical analysis we use
# ----> 9 import geopandas as gpd #To read our data
#      10 import folium #for interactive maps
#      11 from folium import Circle, Marker #to select the maptype we want to use
#      12 from folium.plugins import HeatMap, MarkerCluster #for plugins
#
# File /opt/anaconda3/envs/cc/lib/python3.13/site-packages/geopandas/__init__.py:3
#       1 from geopandas._config import options  # noqa
# ----> 3 from geopandas.geoseries import GeoSeries  # noqa
#       4 from geopandas.geodataframe import GeoDataFrame  # noqa
#       5 from geopandas.array import points_from_xy  # noqa
#
# File /opt/anaconda3/envs/cc/lib/python3.13/site-packages/geopandas/geoseries.py:12
#       9 from pyproj import CRS
#      10 from shapely.geometry.base import BaseGeometry
# ---> 12 from geopandas.base import GeoPandasBase, _delegate_property
#      13 from geopandas.plotting import plot_series
#      15 from .array import (
#      16     GeometryDtype,
#      17     from_shapely,
#    (...)     21     to_wkt,
#      22 )
#
# File /opt/anaconda3/envs/cc/lib/python3.13/site-packages/geopandas/base.py:9
#       7 from shapely.geometry import box
#       8 from shapely.geometry.base import BaseGeometry
# ----> 9 from shapely.ops import cascaded_union
#      11 from .array import GeometryArray, GeometryDtype
#      14 def is_geometry_type(data):
#
# ImportError: cannot import name 'cascaded_union' from 'shapely.ops' (/opt/anaconda3/envs/cc/lib/python3.13/site-packages/shapely/ops.py)
